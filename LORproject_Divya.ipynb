# %% [markdown]
# # Logistics Project on Breast Cancer Prediction

# %% [markdown]
# # Collection of Data

# %%
# import Libraries
import numpy as np
import pandas as pd
import seaborn as sns
from matplotlib import pyplot as plt
# %matplotlib inline

# %%
#load dataset
df=pd.read_csv('data.csv')

# %%
#read the data
df
# Out:
#            id diagnosis  Radius_mean  Texture_mean  perimeter_mean  area_mean  \
# 0      842302         M        17.99         10.38          122.80     1001.0
# 1      842517         M          NaN         21.77          132.90     1326.0
# 2    84300903         M        19.69         21.25          130.00     1203.0
# 3    84348301         M        11.42         20.38           77.58      386.1
# 4    84358402         M        20.29         14.34          135.10     1297.0
# ..        ...       ...          ...           ...             ...        ...
# 564    926424         M        21.56         22.39          142.00     1479.0
# 565    926682         M        20.13         28.25          131.20     1261.0
# 566    926954         M        16.60         28.08          108.30      858.1
# 567    927241         M        20.60         29.33          140.10     1265.0
# 568     92751         B         7.76         24.54           47.92      181.0
#
# ...

# %% [markdown]
# # Information about dataset

# %%
#shape of the data i.e no. of rows and columns
df.shape
# Out:
# (569, 32)

# %%
# top 10 rows
df.head(10)
# Out:
#          id diagnosis  Radius_mean  Texture_mean  perimeter_mean  area_mean  \
# 0    842302         M        17.99         10.38          122.80     1001.0
# 1    842517         M          NaN         21.77          132.90     1326.0
# 2  84300903         M        19.69         21.25          130.00     1203.0
# 3  84348301         M        11.42         20.38           77.58      386.1
# 4  84358402         M        20.29         14.34          135.10     1297.0
# 5    843786         M        12.45         15.70           82.57      477.1
# 6    844359         M        18.25         19.98          119.60     1040.0
# 7  84458202         M        13.71         20.83           90.20      577.9
# 8    844981         M        13.00         21.82           87.50      519.8
# 9  84501001         M        12.46         24.04           83.97      475.9
#
#    smoothness_mean  compactness_mean  concavity_mean  concave points_mean  \
# ...

# %%
#bottom 10 rows
df.tail(10)
# Out:
#          id diagnosis  Radius_mean  Texture_mean  perimeter_mean  area_mean  \
# 559  925291         B        11.51         23.93           74.52      403.5
# 560  925292         B        14.05         27.15           91.38      600.4
# 561  925311         B        11.20         29.37           70.67      386.0
# 562  925622         M        15.22         30.62          103.40      716.9
# 563  926125         M        20.92         25.09          143.00     1347.0
# 564  926424         M        21.56         22.39          142.00     1479.0
# 565  926682         M        20.13         28.25          131.20     1261.0
# 566  926954         M        16.60         28.08          108.30      858.1
# 567  927241         M        20.60         29.33          140.10     1265.0
# 568   92751         B         7.76         24.54           47.92      181.0
#
#      smoothness_mean  compactness_mean  concavity_mean  concave points_mean  \
# ...

# %%
# describe :count,max,min
df.describe(include='all')
# Out:
#                   id diagnosis  Radius_mean  Texture_mean  perimeter_mean  \
# count   5.690000e+02       569   561.000000    569.000000      569.000000
# unique           NaN         2          NaN           NaN             NaN
# top              NaN         B          NaN           NaN             NaN
# freq             NaN       357          NaN           NaN             NaN
# mean    3.037183e+07       NaN    14.094490     19.296678       91.969033
# std     1.250206e+08       NaN     3.527931      4.301816       24.298981
# min     8.670000e+03       NaN     6.981000      9.710000       43.790000
# 25%     8.692180e+05       NaN    11.680000     16.170000       75.170000
# 50%     9.060240e+05       NaN    13.280000     18.870000       86.240000
# 75%     8.813129e+06       NaN    15.750000     21.800000      104.100000
# max     9.113205e+08       NaN    28.110000     39.280000      188.500000
#
#           area_mean  smoothness_mean  compactness_mean  concavity_mean  \
# ...

# %%
#it will display information about that object, including its data type, attributes, and methods, if available. 
#This information is provided interactively to help you understand the object better.
df.info
# Out:
# <bound method DataFrame.info of            id diagnosis  Radius_mean  Texture_mean  perimeter_mean  area_mean  \
# 0      842302         M        17.99         10.38          122.80     1001.0
# 1      842517         M          NaN         21.77          132.90     1326.0
# 2    84300903         M        19.69         21.25          130.00     1203.0
# 3    84348301         M        11.42         20.38           77.58      386.1
# 4    84358402         M        20.29         14.34          135.10     1297.0
# ..        ...       ...          ...           ...             ...        ...
# 564    926424         M        21.56         22.39          142.00     1479.0
# 565    926682         M        20.13         28.25          131.20     1261.0
# 566    926954         M        16.60         28.08          108.30      858.1
# 567    927241         M        20.60         29.33          140.10     1265.0
# 568     92751         B         7.76         24.54           47.92      181.0
#
# ...

# %%
#it provides a concise summary of the DataFrame's structure,
#including the number of non-null values, data types of columns, and memory usage. 
#It's a useful method for quickly assessing the basic characteristics of your data.
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 569 entries, 0 to 568
# Data columns (total 32 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   id                       569 non-null    int64
#  1   diagnosis                569 non-null    object
#  2   Radius_mean              561 non-null    float64
#  3   Texture_mean             569 non-null    float64
#  4   perimeter_mean           569 non-null    float64
#  5   area_mean                569 non-null    float64
#  6   smoothness_mean          569 non-null    float64
#  7   compactness_mean         567 non-null    float64
#  8   concavity_mean           569 non-null    float64
#  9   concave points_mean      569 non-null    float64
#  10  symmetry_mean            569 non-null    float64
#  11  fractal_dimension_mean   569 non-null    float64
#  12  radius_se                569 non-null    float64
#  13  texture_se               569 non-null    float64
# ...

# %% [markdown]
# # Data Preprocessing(treating missing values)

# %%
#any null value present
df.isnull().values.any()
# Out:
# True

# %%
# check the null values entirely present in the dataset
df.isnull()
# Out:
#         id  diagnosis  Radius_mean  Texture_mean  perimeter_mean  area_mean  \
# 0    False      False        False         False           False      False
# 1    False      False         True         False           False      False
# 2    False      False        False         False           False      False
# 3    False      False        False         False           False      False
# 4    False      False        False         False           False      False
# ..     ...        ...          ...           ...             ...        ...
# 564  False      False        False         False           False      False
# 565  False      False        False         False           False      False
# 566  False      False        False         False           False      False
# 567  False      False        False         False           False      False
# 568  False      False        False         False           False      False
#
# ...

# %%
# number of null values in each column
df.isnull().sum()
# Out:
# id                         0
# diagnosis                  0
# Radius_mean                8
# Texture_mean               0
# perimeter_mean             0
# area_mean                  0
# smoothness_mean            0
# compactness_mean           2
# concavity_mean             0
# concave points_mean        0
# symmetry_mean              0
# fractal_dimension_mean     0
# radius_se                  0
# texture_se                 0
# perimeter_se               0
# area_se                    8
# smoothness_se              0
# compactness_se             0
# concavity_se               0
# concave points_se          0
# symmetry_se                0
# fractal_dimension_se       0
# radius_worst               0
# texture_worst              0
# perimeter_worst            3
# area_worst                 0
# smoothness_worst           0
# compactness_worst          0
# concavity_worst            0
# concave points_worst       5
# symmetry_worst             0
# fractal_dimension_worst    0
# ...

# %%
# to illustrate null values using heatmap
sns.heatmap(df.isnull(), yticklabels=False,cmap='viridis')
# Out:
# <Axes: >

# %%
df['Radius_mean'].bfill(axis=0, inplace=True)
df['compactness_mean']=df['compactness_mean'].fillna(df['compactness_mean'].mode()[0])
df['area_se']=df['area_se'].fillna(df['area_se'].mean())
df['perimeter_worst'].ffill(axis=0, inplace=True)
df['concave points_worst'].bfill(axis=0, inplace=True)

# %%
# number of null values in each column
df.isnull().sum()
# Out:
# id                         0
# diagnosis                  0
# Radius_mean                0
# Texture_mean               0
# perimeter_mean             0
# area_mean                  0
# smoothness_mean            0
# compactness_mean           0
# concavity_mean             0
# concave points_mean        0
# symmetry_mean              0
# fractal_dimension_mean     0
# radius_se                  0
# texture_se                 0
# perimeter_se               0
# area_se                    0
# smoothness_se              0
# compactness_se             0
# concavity_se               0
# concave points_se          0
# symmetry_se                0
# fractal_dimension_se       0
# radius_worst               0
# texture_worst              0
# perimeter_worst            0
# area_worst                 0
# smoothness_worst           0
# compactness_worst          0
# concavity_worst            0
# concave points_worst       0
# symmetry_worst             0
# fractal_dimension_worst    0
# ...

# %%
# to illustrate null values using heatmap
sns.heatmap(df.isnull(), yticklabels=False,cmap='viridis')
# Out:
# <Axes: >

# %% [markdown]
# # Statastical Data

# %%
df.mean()
df.median()
df.mode()
df.std()
df.sem()
df.var()
df.quantile()
# Out:
# C:\Users\Diksha\AppData\Local\Temp\ipykernel_5944\2462740087.py:1: FutureWarning: The default value of numeric_only in DataFrame.mean is deprecated. In a future version, it will default to False. In addition, specifying 'numeric_only=None' is deprecated. Select only valid columns or specify the value of numeric_only to silence this warning.
#   df.mean()
# C:\Users\Diksha\AppData\Local\Temp\ipykernel_5944\2462740087.py:2: FutureWarning: The default value of numeric_only in DataFrame.median is deprecated. In a future version, it will default to False. In addition, specifying 'numeric_only=None' is deprecated. Select only valid columns or specify the value of numeric_only to silence this warning.
#   df.median()
# ...

# %%
df['diagnosis'].value_counts()
# Out:
# B    357
# M    212
# Name: diagnosis, dtype: int64

# %%
df=df.replace({'diagnosis':{'B': 0, 'M': 1}})

# %%
df
# Out:
#            id  diagnosis  Radius_mean  Texture_mean  perimeter_mean  \
# 0      842302          1        17.99         10.38          122.80
# 1      842517          1        19.69         21.77          132.90
# 2    84300903          1        19.69         21.25          130.00
# 3    84348301          1        11.42         20.38           77.58
# 4    84358402          1        20.29         14.34          135.10
# ..        ...        ...          ...           ...             ...
# 564    926424          1        21.56         22.39          142.00
# 565    926682          1        20.13         28.25          131.20
# 566    926954          1        16.60         28.08          108.30
# 567    927241          1        20.60         29.33          140.10
# 568     92751          0         7.76         24.54           47.92
#
#      area_mean  smoothness_mean  compactness_mean  concavity_mean  \
# 0       1001.0          0.11840           0.27760         0.30010
# ...

# %%
df.dtypes
# Out:
# id                           int64
# diagnosis                    int64
# Radius_mean                float64
# Texture_mean               float64
# perimeter_mean             float64
# area_mean                  float64
# smoothness_mean            float64
# compactness_mean           float64
# concavity_mean             float64
# concave points_mean        float64
# symmetry_mean              float64
# fractal_dimension_mean     float64
# radius_se                  float64
# texture_se                 float64
# perimeter_se               float64
# area_se                    float64
# smoothness_se              float64
# compactness_se             float64
# concavity_se               float64
# concave points_se          float64
# symmetry_se                float64
# fractal_dimension_se       float64
# radius_worst               float64
# texture_worst              float64
# perimeter_worst            float64
# area_worst                 float64
# smoothness_worst           float64
# ...

# %%
corrmat = df.corr()
corrmat["diagnosis"].sort_values(ascending=False)
# Out:
# diagnosis                  1.000000
# concave points_worst       0.791842
# perimeter_worst            0.779275
# concave points_mean        0.776614
# radius_worst               0.776454
# perimeter_mean             0.742636
# area_worst                 0.733825
# Radius_mean                0.728619
# area_mean                  0.708984
# concavity_mean             0.696360
# concavity_worst            0.659610
# compactness_mean           0.595141
# compactness_worst          0.590998
# radius_se                  0.567134
# perimeter_se               0.556141
# area_se                    0.543815
# texture_worst              0.456903
# smoothness_worst           0.421465
# Texture_mean               0.417232
# symmetry_worst             0.416294
# concave points_se          0.408042
# smoothness_mean            0.358560
# symmetry_mean              0.330499
# fractal_dimension_worst    0.323872
# compactness_se             0.292999
# concavity_se               0.253730
# ...

# %%
df.columns
# Out:
# Index(['id', 'diagnosis', 'Radius_mean', 'Texture_mean', 'perimeter_mean',
#        'area_mean', 'smoothness_mean', 'compactness_mean', 'concavity_mean',
#        'concave points_mean', 'symmetry_mean', 'fractal_dimension_mean',
#        'radius_se', 'texture_se', 'perimeter_se', 'area_se', 'smoothness_se',
#        'compactness_se', 'concavity_se', 'concave points_se', 'symmetry_se',
#        'fractal_dimension_se', 'radius_worst', 'texture_worst',
#        'perimeter_worst', 'area_worst', 'smoothness_worst',
#        'compactness_worst', 'concavity_worst', 'concave points_worst',
#        'symmetry_worst', 'fractal_dimension_worst'],
#       dtype='object')

# %% [markdown]
# # Data Visualization

# %%
#Examaning a correlation matrix of all the features 
corrmat = df.corr()
plt.subplots(figsize=(18,18))
sns.heatmap(corrmat,cmap="Pastel1", square=True)
# Out:
# <Axes: >

# %%
plt.figure(figsize = (18,9))
sns.heatmap(df.corr(), cmap='GnBu', annot=True)
plt.show()

# %%
sns.countplot(x='diagnosis', data=df)
plt.title('Bar Plot of Diagnosis')
plt.xlabel('Diagnosis')
plt.ylabel('Count')
plt.show()

# %%
diagnosis_counts = df['diagnosis'].value_counts()
plt.pie(diagnosis_counts, labels=diagnosis_counts.index, autopct='%1.1f%%', startangle=90)
plt.title('Pie Chart of Diagnosis Distribution')
plt.axis('equal')
plt.show()

# %%
features = ['concave points_worst','perimeter_worst', 'concave points_mean','radius_worst', 'perimeter_mean','area_worst', 
            'Radius_mean','area_mean', 'concavity_mean', 'concavity_worst', 'compactness_mean', 'compactness_worst',
            'radius_se', 'perimeter_se', 'area_se']
for i in features:
    sns.swarmplot(x=df["diagnosis"], y=df[i], color="black", alpha=0.5 )
    sns.boxenplot(x=df["diagnosis"], y=df[i])
    plt.show()
# Out:
# C:\Users\Diksha\anaconda3\Lib\site-packages\seaborn\categorical.py:3544: UserWarning: 17.6% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)
# C:\Users\Diksha\anaconda3\Lib\site-packages\seaborn\categorical.py:3544: UserWarning: 18.5% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)
# C:\Users\Diksha\anaconda3\Lib\site-packages\seaborn\categorical.py:3544: UserWarning: 17.4% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)
# C:\Users\Diksha\anaconda3\Lib\site-packages\seaborn\categorical.py:3544: UserWarning: 13.7% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)
# ...

# %%
sns.kdeplot(df['Radius_mean'], shade=True)
plt.title('KDE Plot of Radius Mean')
plt.xlabel('Radius Mean')
plt.ylabel('Density')
plt.show()
# Out:
# C:\Users\Diksha\AppData\Local\Temp\ipykernel_5944\2699181838.py:1: FutureWarning:
#
# `shade` is now deprecated in favor of `fill`; setting `fill=True`.
# This will become an error in seaborn v0.14.0; please update your code.
#
#   sns.kdeplot(df['Radius_mean'], shade=True)

# %%
plt.plot(df['area_mean'])
plt.title('Line Plot of area_mean')
plt.xlabel('Index')
plt.ylabel('area_mean')
plt.show()

# %%
sns.pairplot(df[['Radius_mean', 'area_mean', 'smoothness_mean', 'diagnosis']], hue='diagnosis', markers=['o', 's'], palette='husl')
plt.show()

# %%
sns.scatterplot(x='Radius_mean', y='area_mean', hue='diagnosis', data=df)
plt.title('Scatter Plot of Radius Mean vs. Area Mean')
plt.xlabel('Radius Mean')
plt.ylabel('Area Mean')
plt.show()

# %%
sns.violinplot(x='diagnosis', y='area_mean', data=df, inner='quart')
plt.title('Violin Plot of Area Mean by Diagnosis')
plt.xlabel('Diagnosis')
plt.ylabel('Area Mean')
plt.show()

# %%
plt.hist(df['Radius_mean'], bins=20, color='skyblue', alpha=0.7)
plt.title('Histogram of Radius Mean')
plt.xlabel('Radius Mean')
plt.ylabel('Frequency')
plt.show()

# %% [markdown]
# # Detection of Outliers and treating of Outliers

# %%
from scipy import stats
z_scores = stats.zscore(df['Radius_mean'])
z_score_outliers = (z_scores < -3) | (z_scores > 3)
z_score_outlier_rows = df[z_score_outliers]
print("Outliers Detected by Z-Score:")
print(z_score_outlier_rows)
threshold = 3
dno1 = df[(z_scores < threshold) & (z_scores > -threshold)]
# Out:
# Outliers Detected by Z-Score:
#             id  diagnosis  Radius_mean  Texture_mean  perimeter_mean  \
# 82     8611555          1        25.22         24.91           171.5
# 180     873592          1        27.22         21.87           182.1
# 212    8810703          1        28.11         18.47           188.5
# 352     899987          1        25.73         17.46           174.2
# 461  911296202          1        27.42         26.27           186.9
#
#      area_mean  smoothness_mean  compactness_mean  concavity_mean  \
# 82      1878.0           0.1063            0.2665          0.3339
# 180     2250.0           0.1094            0.1914          0.2871
# 212     2499.0           0.1142            0.1516          0.3201
# 352     2010.0           0.1149            0.2363          0.3368
# 461     2501.0           0.1084            0.1988          0.3635
#
#      concave points_mean  ...  radius_worst  texture_worst  perimeter_worst  \
# ...

# %%
from scipy import stats
z_scores = stats.zscore(dno1['perimeter_mean'])
z_score_outliers = (z_scores < -3) | (z_scores > 3)
z_score_outlier_rows = dno1[z_score_outliers]
print("Outliers Detected by Z-Score:")
print(z_score_outlier_rows)
threshold = 3
dno2 = dno1[(z_scores < threshold) & (z_scores > -threshold)]
# Out:
# Outliers Detected by Z-Score:
#            id  diagnosis  Radius_mean  Texture_mean  perimeter_mean  \
# 122    865423          1        24.25          20.2           166.2
# 521  91762702          1        24.63          21.6           165.5
#
#      area_mean  smoothness_mean  compactness_mean  concavity_mean  \
# 122     1761.0           0.1447            0.2867          0.4268
# 521     1841.0           0.1030            0.2106          0.2310
#
#      concave points_mean  ...  radius_worst  texture_worst  perimeter_worst  \
# 122               0.2012  ...         26.02          23.99            180.9
# 521               0.1471  ...         29.92          26.93            205.7
#
#      area_worst  smoothness_worst  compactness_worst  concavity_worst  \
# 122      2073.0            0.1696             0.4244           0.5803
# 521      2642.0            0.1342             0.4188           0.4658
#
#      concave points_worst  symmetry_worst  fractal_dimension_worst
# ...

# %%
from scipy import stats
z_scores = stats.zscore(dno2['perimeter_worst'])
z_score_outliers = (z_scores < -3) | (z_scores > 3)
z_score_outlier_rows = dno2[z_score_outliers]
print("Outliers Detected by Z-Score:")
print(z_score_outlier_rows)
threshold = 3
dno3 = dno2[(z_scores < threshold) & (z_scores > -threshold)]
# Out:
# Outliers Detected by Z-Score:
#            id  diagnosis  Radius_mean  Texture_mean  perimeter_mean  \
# 108     86355          1        22.27         19.67           152.8
# 236  88299702          1        23.21         26.97           153.5
# 265  88995002          1        20.73         31.12           135.7
# 339     89812          1        23.51         24.27           155.1
# 503    915143          1        23.09         19.83           152.1
#
#      area_mean  smoothness_mean  compactness_mean  concavity_mean  \
# 108     1509.0          0.13260            0.2768          0.4264
# 236     1670.0          0.09509            0.1682          0.1950
# 265     1419.0          0.09469            0.1147          0.1367
# 339     1747.0          0.10690            0.1283          0.2308
# 503     1682.0          0.09342            0.1275          0.1676
#
#      concave points_mean  ...  radius_worst  texture_worst  perimeter_worst  \
# ...

# %%
from scipy import stats
z_scores = stats.zscore(dno3['concave points_mean'])
z_score_outliers = (z_scores < -3) | (z_scores > 3)
z_score_outlier_rows = dno3[z_score_outliers]
print("Outliers Detected by Z-Score:")
print(z_score_outlier_rows)
threshold = 3
dno4 = dno3[(z_scores < threshold) & (z_scores > -threshold)]
# Out:
# Outliers Detected by Z-Score:
#           id  diagnosis  Radius_mean  Texture_mean  perimeter_mean  area_mean  \
# 78   8610862          1        20.18         23.97           143.7     1245.0
# 202   878796          1        23.29         26.67           158.9     1685.0
# 393   903516          1        21.61         22.28           144.4     1407.0
#
#      smoothness_mean  compactness_mean  concavity_mean  concave points_mean  \
# 78            0.1286            0.3454          0.3754               0.1604
# 202           0.1141            0.2084          0.3523               0.1620
# 393           0.1167            0.2087          0.2810               0.1562
#
#      ...  radius_worst  texture_worst  perimeter_worst  area_worst  \
# 78   ...         23.37          31.72            170.3      1623.0
# 202  ...         25.12          32.68            177.0      1986.0
# 393  ...         26.23          28.74            172.0      2081.0
#
# ...

# %%
from scipy import stats
z_scores = stats.zscore(dno4['radius_worst'])
z_score_outliers = (z_scores < -3) | (z_scores > 3)
z_score_outlier_rows = dno4[z_score_outliers]
print("Outliers Detected by Z-Score:")
print(z_score_outlier_rows)
threshold = 3
dno5 = dno4[(z_scores < threshold) & (z_scores > -threshold)]
# Out:
# Outliers Detected by Z-Score:
#           id  diagnosis  Radius_mean  Texture_mean  perimeter_mean  area_mean  \
# 23    851509          1        21.16         23.04           137.2     1404.0
# 368  9011971          1        21.71         17.25           140.9     1546.0
#
#      smoothness_mean  compactness_mean  concavity_mean  concave points_mean  \
# 23           0.09428           0.10220          0.1097              0.08632
# 368          0.09384           0.08562          0.1168              0.08465
#
#      ...  radius_worst  texture_worst  perimeter_worst  area_worst  \
# 23   ...         29.17          35.59            188.0      2615.0
# 368  ...         30.75          26.44            199.5      3143.0
#
#      smoothness_worst  compactness_worst  concavity_worst  \
# 23             0.1401             0.2600           0.3155
# 368            0.1363             0.1628           0.2861
#
#      concave points_worst  symmetry_worst  fractal_dimension_worst
# ...

# %%
from scipy import stats
z_scores = stats.zscore(dno5['area_mean'])
z_score_outliers = (z_scores < -3) | (z_scores > 3)
z_score_outlier_rows = dno5[z_score_outliers]
print("Outliers Detected by Z-Score:")
print(z_score_outlier_rows)
threshold = 3
dno6 = dno5[(z_scores < threshold) & (z_scores > -threshold)]
# Out:
# Outliers Detected by Z-Score:
#           id  diagnosis  Radius_mean  Texture_mean  perimeter_mean  area_mean  \
# 164  8712289          1        23.27         22.04           152.1     1686.0
# 272  8910988          1        21.75         20.99           147.3     1491.0
#
#      smoothness_mean  compactness_mean  concavity_mean  concave points_mean  \
# 164          0.08439            0.1145          0.1324              0.09702
# 272          0.09401            0.1961          0.2195              0.10880
#
#      ...  radius_worst  texture_worst  perimeter_worst  area_worst  \
# 164  ...         28.01          28.22            184.2      2403.0
# 272  ...         28.19          28.18            195.9      2384.0
#
#      smoothness_worst  compactness_worst  concavity_worst  \
# 164            0.1228             0.3583           0.3948
# 272            0.1272             0.4725           0.5807
#
#      concave points_worst  symmetry_worst  fractal_dimension_worst
# ...

# %%
from scipy import stats
z_scores = stats.zscore(dno6['smoothness_mean'])
z_score_outliers = (z_scores < -3) | (z_scores > 3)
z_score_outlier_rows = dno6[z_score_outliers]
print("Outliers Detected by Z-Score:")
print(z_score_outlier_rows)
threshold = 3
dno7= dno6[(z_scores < threshold) & (z_scores > -threshold)]
# Out:
# Outliers Detected by Z-Score:
#            id  diagnosis  Radius_mean  Texture_mean  perimeter_mean  \
# 3    84348301          1       11.420         20.38           77.58
# 105    863030          1       13.110         15.56           87.21
# 504    915186          0        9.268         12.87           61.49
# 568     92751          0        7.760         24.54           47.92
#
#      area_mean  smoothness_mean  compactness_mean  concavity_mean  \
# 3        386.1          0.14250           0.28390          0.2414
# 105      530.2          0.13980           0.17650          0.2071
# 504      248.7          0.16340           0.22390          0.0973
# 568      181.0          0.05263           0.04362          0.0000
#
#      concave points_mean  ...  radius_worst  texture_worst  perimeter_worst  \
# 3                0.10520  ...        14.910          26.50            98.87
# 105              0.09601  ...        16.310          22.40           106.40
# ...

# %%
from scipy import stats
z_scores = stats.zscore(dno7['concavity_worst'])
z_score_outliers = (z_scores < -3) | (z_scores > 3)
z_score_outlier_rows = dno7[z_score_outliers]
print("Outliers Detected by Z-Score:")
print(z_score_outlier_rows)
threshold = 3
dno8 = dno7[(z_scores < threshold) & (z_scores > -threshold)]
# Out:
# Outliers Detected by Z-Score:
#            id  diagnosis  Radius_mean  Texture_mean  perimeter_mean  \
# 9    84501001          1       12.460         24.04           83.97
# 68     859471          0        9.029         17.33           58.79
# 400  90439701          1       17.910         21.02          124.40
# 430    907914          1       14.900         22.53          102.10
# 562    925622          1       15.220         30.62          103.40
# 567    927241          1       20.600         29.33          140.10
#
#      area_mean  smoothness_mean  compactness_mean  concavity_mean  \
# 9        475.9          0.11860            0.2396          0.2273
# 68       250.5          0.10660            0.1413          0.3130
# 400      994.0          0.12300            0.2576          0.3189
# 430      685.0          0.09947            0.2225          0.2733
# 562      716.9          0.10480            0.2087          0.2550
# ...

# %%
from scipy import stats
z_scores = stats.zscore(dno8['compactness_mean'])
z_score_outliers = (z_scores < -3) | (z_scores > 3)
z_score_outlier_rows = dno8[z_score_outliers]
print("Outliers Detected by Z-Score:")
print(z_score_outlier_rows)
threshold = 3
dno9= dno8[(z_scores < threshold) & (z_scores > -threshold)]
# Out:
# Outliers Detected by Z-Score:
#          id  diagnosis  Radius_mean  Texture_mean  perimeter_mean  area_mean  \
# 0    842302          1        17.99         10.38          122.80     1001.0
# 12   846226          1        19.17         24.80          132.40     1123.0
# 181  873593          1        21.09         26.57          142.70     1311.0
# 190  874858          1        14.22         23.12           94.37      609.9
# 258  887181          1        15.66         23.20          110.20      773.5
#
#      smoothness_mean  compactness_mean  concavity_mean  concave points_mean  \
# 0             0.1184            0.2776          0.3001              0.14710
# 12            0.0974            0.2458          0.2065              0.11180
# 181           0.1141            0.2832          0.2487              0.14960
# 190           0.1075            0.2413          0.1981              0.06618
# 258           0.1109            0.3114          0.3176              0.13770
#
# ...

# %%
from scipy import stats
z_scores = stats.zscore(dno9['compactness_worst'])
z_score_outliers = (z_scores < -3) | (z_scores > 3)
z_score_outlier_rows = dno9[z_score_outliers]
print("Outliers Detected by Z-Score:")
print(z_score_outlier_rows)
threshold = 3
dno10 = dno9[(z_scores < threshold) & (z_scores > -threshold)]
# Out:
# Outliers Detected by Z-Score:
#            id  diagnosis  Radius_mean  Texture_mean  perimeter_mean  \
# 14   84667401          1        13.73         22.61           93.60
# 15   84799002          1        14.54         27.54           96.73
# 26     852763          1        14.58         21.53           97.41
# 33     854002          1        19.27         26.47          127.90
# 42     855625          1        19.07         24.81          128.30
# 72     859717          1        17.20         24.52          114.20
# 379   9013838          1        11.08         18.83           73.30
#
#      area_mean  smoothness_mean  compactness_mean  concavity_mean  \
# 14       578.3          0.11310            0.2293          0.2128
# 15       658.8          0.11390            0.1595          0.1639
# 26       644.8          0.10540            0.1868          0.1425
# 33      1162.0          0.09401            0.1719          0.1657
# ...

# %%
from scipy import stats
z_scores = stats.zscore(dno10['radius_se'])
z_score_outliers = (z_scores < -3) | (z_scores > 3)
z_score_outlier_rows = dno10[z_score_outliers]
print("Outliers Detected by Z-Score:")
print(z_score_outlier_rows)
threshold = 3
data_no_outliers = dno10[(z_scores < threshold) & (z_scores > -threshold)]
# Out:
# Outliers Detected by Z-Score:
#            id  diagnosis  Radius_mean  Texture_mean  perimeter_mean  \
# 25     852631          1        17.14         16.40          116.00
# 38     855133          1        14.99         25.20           95.54
# 138    868826          1        14.95         17.57           96.85
# 168   8712766          1        17.47         24.68          116.10
# 250    884948          1        20.94         23.56          138.90
# 300    892438          1        19.53         18.90          129.50
# 302  89263202          1        20.09         23.86          134.70
# 369   9012000          1        22.01         21.90          147.20
# 417  90602302          1        15.50         21.08          102.90
# 564    926424          1        21.56         22.39          142.00
#
#      area_mean  smoothness_mean  compactness_mean  concavity_mean  \
# 25       912.7          0.11860           0.22760         0.22290
# ...

# %%
data_no_outliers
# Out:
#            id  diagnosis  Radius_mean  Texture_mean  perimeter_mean  \
# 1      842517          1        19.69         21.77          132.90
# 2    84300903          1        19.69         21.25          130.00
# 4    84358402          1        20.29         14.34          135.10
# 5      843786          1        12.45         15.70           82.57
# 6      844359          1        18.25         19.98          119.60
# ..        ...        ...          ...           ...             ...
# 560    925292          0        14.05         27.15           91.38
# 561    925311          0        11.20         29.37           70.67
# 563    926125          1        20.92         25.09          143.00
# 565    926682          1        20.13         28.25          131.20
# 566    926954          1        16.60         28.08          108.30
#
#      area_mean  smoothness_mean  compactness_mean  concavity_mean  \
# 1       1326.0          0.08474           0.07864         0.08690
# ...

# %% [markdown]
# # Logistics Regression

# %%
#formation of Model
from sklearn.preprocessing import OneHotEncoder,StandardScaler
categorical_cols=["symmetry_worst"]
encoder=OneHotEncoder(drop='first',sparse=False)
encoder_cols=pd.DataFrame(encoder.fit_transform(data_no_outliers[categorical_cols]),columns=encoder.get_feature_names_out(categorical_cols))
numerical_cols=['id','Radius_mean', 'Texture_mean', 'perimeter_mean',
       'area_mean', 'smoothness_mean', 'compactness_mean', 'concavity_mean',
       'concave points_mean', 'symmetry_mean', 'fractal_dimension_mean',
       'radius_se', 'texture_se', 'perimeter_se', 'area_se', 'smoothness_se',
       'compactness_se', 'concavity_se', 'concave points_se', 'symmetry_se',
       'fractal_dimension_se', 'radius_worst', 'texture_worst',
       'perimeter_worst', 'area_worst', 'smoothness_worst',
       'compactness_worst', 'concavity_worst', 'concave points_worst',
       'fractal_dimension_worst']
scaler=StandardScaler()
scaled_cols=pd.DataFrame(scaler.fit_transform(data_no_outliers[numerical_cols]),columns=scaler.get_feature_names_out(numerical_cols))
# Out:
# C:\Users\Diksha\anaconda3\Lib\site-packages\sklearn\preprocessing\_encoders.py:868: FutureWarning: `sparse` was renamed to `sparse_output` in version 1.2 and will be removed in 1.4. `sparse_output` is ignored unless you leave `sparse` to its default value.
#   warnings.warn(

# %%
#X&Y
X=pd.concat([encoder_cols,scaled_cols],axis=1)
Y=data_no_outliers['diagnosis']

# %%
#Importing Libraries
import sklearn 
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LogisticRegression
from sklearn import metrics
from sklearn.metrics import confusion_matrix
from sklearn.model_selection import GridSearchCV
from sklearn.metrics import accuracy_score, precision_score, recall_score, f1_score, roc_auc_score
from sklearn.utils.fixes import loguniform
from sklearn.model_selection import RandomizedSearchCV

# %%
#train the model
X_train,X_test, Y_train, Y_test = train_test_split(X,Y, test_size=0.2,random_state=30)

# %%
log = LogisticRegression()

# %%
#build the model
log.fit(X_train, Y_train)
# Out:
# LogisticRegression()

# %%
Train_score = log.score(X_train,Y_train)
print('Train_score: ',Train_score)
# Out:
# Train_score:  0.9903381642512077

# %%
Test_score = log.score(X_test, Y_test)
print('Test_Score: ',Test_score)
# Out:
# Test_Score:  0.9711538461538461

# %%
pred_train = log.predict(X_train)
pred_test = log.predict(X_test)

# %%
print(metrics.classification_report(Y_train, pred_train))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.99      1.00      0.99       284
#            1       1.00      0.97      0.98       130
#
#     accuracy                           0.99       414
#    macro avg       0.99      0.98      0.99       414
# weighted avg       0.99      0.99      0.99       414

# %%
roc = log.predict_proba(X_train)[:,1]

fpr,tpr,threshold = metrics.roc_curve(Y_train, roc)
plt.plot([0,1],[0,1],'k--')
plt.plot(fpr,tpr, label='logistic')
plt.ylabel('FPR')
plt.xlabel('TPR')
plt.show()

# %%
metrics.roc_auc_score(Y_train, roc)
# Out:
# 0.9982665222101842

# %%
cm = confusion_matrix(Y_test,pred_test)
print('Confusion Matrix: ',cm)
# Out:
# Confusion Matrix:  [[69  1]
#  [ 2 32]]

# %%
plt.figure(figsize = (10,7))
sns.heatmap(cm, annot=True)
plt.title('Confusion Matrix - Test Data')
plt.xlabel('Predicted Label')
plt.ylabel('True Label')
# Out:
# Text(95.72222222222221, 0.5, 'True Label')

# %% [markdown]
# # Tuning

# %%
param_grid = {
    'penalty':['l1', 'l2'],
    'C' : [0.1, 0.5, 1, 5, 10]
}

# %%
grid = GridSearchCV(estimator = log, param_grid=param_grid, cv = 5)

# %%
grid.fit(X_train, Y_train)
# Out:
# C:\Users\Diksha\anaconda3\Lib\site-packages\sklearn\model_selection\_validation.py:378: FitFailedWarning:
# 25 fits failed out of a total of 50.
# The score on these train-test partitions for these parameters will be set to nan.
# If these failures are not expected, you can try to debug them by setting error_score='raise'.
#
# Below are more details about the failures:
# --------------------------------------------------------------------------------
# 25 fits failed with the following error:
# Traceback (most recent call last):
#   File "C:\Users\Diksha\anaconda3\Lib\site-packages\sklearn\model_selection\_validation.py", line 686, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "C:\Users\Diksha\anaconda3\Lib\site-packages\sklearn\linear_model\_logistic.py", line 1162, in fit
#     solver = _check_solver(self.solver, self.penalty, self.dual)
#              ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# ...

# %%
best_param = grid.best_params_
best_model = grid.best_estimator_

# %%
y_pred = best_model.predict(X_test)

# %%
acc=accuracy_score(Y_test,y_pred)
pre=precision_score(Y_test,y_pred)
rec=recall_score(Y_test,y_pred)
f1=f1_score(Y_test,y_pred)
roc_auc=roc_auc_score(Y_test,y_pred)

print('Best Param:',best_param)
print('Accuracy:',acc)
print('Precision:',pre)
print('Recall:',rec)
print('F1Score:',f1)
print('ROC_AUC',roc_auc)
# Out:
# Best Param: {'C': 0.5, 'penalty': 'l2'}
# Accuracy: 0.9807692307692307
# Precision: 1.0
# Recall: 0.9411764705882353
# F1Score: 0.9696969696969697
# ROC_AUC 0.9705882352941176

# %%
cm = confusion_matrix(Y_test,y_pred)
print('Confusion Matrix: ',cm)
# Out:
# Confusion Matrix:  [[70  0]
#  [ 2 32]]

# %%
plt.figure(figsize = (10,7))
sns.heatmap(cm, annot=True)
plt.title('Confusion Matrix - Test Data')
plt.xlabel('Predicted Label')
plt.ylabel('True Label')
# Out:
# Text(95.72222222222221, 0.5, 'True Label')

# %%
logistic_random_param={'C':loguniform(1e-4,1e0),
                      'max_iter':(np.arange(100,800,10))}
grid=RandomizedSearchCV(estimator=log, param_distributions=logistic_random_param, cv=5)

# %%
grid.fit(X_train,Y_train)
# Out:
# RandomizedSearchCV(cv=5, estimator=LogisticRegression(),
#                    param_distributions={'C': <scipy.stats._distn_infrastructure.rv_continuous_frozen object at 0x000001CA3AA14950>,
#                                         'max_iter': array([100, 110, 120, 130, 140, 150, 160, 170, 180, 190, 200, 210, 220,
#        230, 240, 250, 260, 270, 280, 290, 300, 310, 320, 330, 340, 350,
#        360, 370, 380, 390, 400, 410, 420, 430, 440, 450, 460, 470, 480,
#        490, 500, 510, 520, 530, 540, 550, 560, 570, 580, 590, 600, 610,
#        620, 630, 640, 650, 660, 670, 680, 690, 700, 710, 720, 730, 740,
#        750, 760, 770, 780, 790])})

# %%
best_param = grid.best_params_
best_model = grid.best_estimator_
y_pred = best_model.predict(X_test)

# %%
acc=accuracy_score(Y_test,y_pred)
pre=precision_score(Y_test,y_pred)
rec=recall_score(Y_test,y_pred)
f1=f1_score(Y_test,y_pred)
roc_auc=roc_auc_score(Y_test,y_pred)

print('Best Param:',best_param)
print('Accuracy:',acc)
print('Precision:',pre)
print('Recall:',rec)





print('F1Score:',f1)
print('ROC_AUC',roc_auc)
# Out:
# Best Param: {'C': 0.13303898708372527, 'max_iter': 510}
# Accuracy: 0.9807692307692307
# Precision: 1.0
# Recall: 0.9411764705882353
# F1Score: 0.9696969696969697
# ROC_AUC 0.9705882352941176

# %%
cm = confusion_matrix(Y_test,y_pred)
print('Confusion Matrix: ',cm)
# Out:
# Confusion Matrix:  [[70  0]
#  [ 2 32]]

# %%
plt.figure(figsize = (10,7))
sns.heatmap(cm, annot=True)
plt.title('Confusion Matrix - Test Data')
plt.xlabel('Predicted Label')
plt.ylabel('True Label')
# Out:
# Text(95.72222222222221, 0.5, 'True Label')
